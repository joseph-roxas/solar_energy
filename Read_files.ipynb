# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from scipy.spatial import cKDTree
import h5pyd
import requests
import os
import sys
import calendar
import seaborn as sns
from tqdm import tqdm
import matplotlib as mpl

# %%
folders = os.listdir("/home/vboxuser/Documents/Data/ME440/")

# %%
file
# Out:
# ['DataSheet_3423694001_1P2W_20230830.csv']

# %%
for i in range(len(folders)):
    file = os.listdir(os.path.join("/home/vboxuser/Documents/Data/ME440/", folders[i]))
    
    f = os.path.join("/home/vboxuser/Documents/Data/ME440/", folders[i], file[0])
    
    df = pd.read_csv(f,header = 1,usecols=['Date', 'Time' ,'Voltage(V)', 'Active Power(W)'])
    df = df.drop(index = 0).reset_index(drop= True)
    df = df.astype({'Date' : str, 
                      'Time' : str, 
                      'Voltage(V)' : float,
                      'Active Power(W)' : float})

    df['datetime'] = df['Date'] + ' ' + df['Time']
    df['datetime'] = df['datetime'].apply(lambda x: pd.to_datetime(x))
    fig, ax = plt.subplots(figsize = (10,3), dpi=140)
    ax.plot(df['datetime'], df['Active Power(W)'], color = 'green')
    plt.show()

# %%
f1 = os.path.join("/home/vboxuser/Documents/Data/ME440/", folders[0], "DataSheet_3423694001_1P2W_20230903.csv")
f2 = os.path.join("/home/vboxuser/Documents/Data/ME440/", folders[1], "DataSheet_3423694001_1P2W_20230824.csv")

# %%
df1 = pd.read_csv(f2,header = 1,usecols=['Date', 'Time' ,'Voltage(V)', 'Active Power(W)'])
df1 = df1.drop(index = 0).reset_index(drop= True)
df1 = df1.astype({'Date' : str, 
                  'Time' : str, 
                  'Voltage(V)' : float,
                  'Active Power(W)' : float})

df1['datetime'] = df1['Date'] + ' ' + df1['Time']
df1['datetime'] = df1['datetime'].apply(lambda x: pd.to_datetime(x))

# %%
fig, ax = plt.subplots(figsize = (10,3), dpi=140)
ax.plot(df1['datetime'], df1['Active Power(W)'], color = 'green')
plt.show()

# %%
df1['Total Active Power Demand(W)'].iloc[0]
# Out:
# 651.41
